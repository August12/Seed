# %%
import tensorflow as tf

x_data = [1,2,3]
y_data = [1,2,3]

W = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.random_uniform([1],-1.0,1.0))

X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")

hypothesis = W * X + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train_op = optimizer.minimize(cost)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(100):
        _, cost_val = sess.run([train_op,cost],feed_dict={X: x_data, Y: y_data})
    
        print(step, cost_val, sess.run(W),sess.run(b))

    print("X: 5, Y:",sess.run(hypothesis,feed_dict={X: 5}))
    print("X: 2.5, Y:",sess.run(hypothesis,feed_dict={X: 2.5}))
# Out:
# 0 23.3926 [1.252701] [-0.01704586]
# 1 0.2810637 [1.0236651] [-0.11471711]
# 2 0.004914356 [1.0474645] [-0.10123973]
# 3 0.001541749 [1.0436602] [-0.09997759]
# 4 0.0014310159 [1.0429018] [-0.09744614]
# 5 0.0013625906 [1.0418386] [-0.09511761]
# 6 0.0012978635 [1.0408363] [-0.09282955]
# 7 0.0012362145 [1.0398543] [-0.09059817]
# 8 0.0011774943 [1.0388962] [-0.08842026]
# 9 0.0011215657 [1.0379611] [-0.0862947]
# 10 0.0010682888 [1.0370486] [-0.08422022]
# 11 0.0010175421 [1.036158] [-0.08219562]
# 12 0.0009692076 [1.0352888] [-0.08021968]
# 13 0.0009231681 [1.0344405] [-0.07829127]
# 14 0.00087932125 [1.0336125] [-0.07640922]
# 15 0.0008375519 [1.0328045] [-0.07457238]
# 16 0.00079776626 [1.0320159] [-0.0727797]
# 17 0.00075987383 [1.0312462] [-0.07103014]
# 18 0.00072377623 [1.0304952] [-0.06932259]
# 19 0.00068939663 [1.029762] [-0.06765614]
# 20 0.00065665174 [1.0290465] [-0.06602973]
# 21 0.0006254575 [1.0283483] [-0.06444239]
# 22 0.0005957466 [1.0276669] [-0.06289323]
# 23 0.00056744926 [1.0270017] [-0.06138135]
# 24 0.00054049393 [1.0263526] [-0.05990577]
# 25 0.00051482144 [1.0257192] [-0.05846568]
# 26 0.00049036654 [1.025101] [-0.0570602]
# 27 0.00046707402 [1.0244975] [-0.05568854]
# 28 0.00044488782 [1.0239086] [-0.05434983]
# 29 0.00042375526 [1.0233338] [-0.05304331]
# 30 0.00040362662 [1.0227729] [-0.05176815]
# 31 0.00038445625 [1.0222254] [-0.0505237]
# 32 0.00036619185 [1.0216912] [-0.0493091]
# 33 0.0003487972 [1.0211698] [-0.04812376]
# 34 0.00033223061 [1.0206608] [-0.04696693]
# 35 0.00031644604 [1.0201643] [-0.04583783]
# 36 0.0003014169 [1.0196794] [-0.04473596]
# 37 0.00028709913 [1.0192064] [-0.04366054]
# 38 0.00027346026 [1.0187447] [-0.04261098]
# 39 0.00026047445 [1.018294] [-0.04158667]
# 40 0.00024810096 [1.0178542] [-0.04058694]
# 41 0.00023631526 [1.0174251] [-0.03961123]
# 42 0.0002250889 [1.0170062] [-0.038659]
# 43 0.00021439676 [1.0165974] [-0.03772966]
# 44 0.00020421452 [1.0161984] [-0.03682269]
# 45 0.00019451289 [1.0158089] [-0.03593751]
# 46 0.00018527287 [1.015429] [-0.03507357]
# 47 0.00017647415 [1.015058] [-0.03423047]
# 48 0.00016809127 [1.014696] [-0.03340759]
# 49 0.00016010473 [1.0143428] [-0.03260446]
# 50 0.00015250132 [1.0139979] [-0.03182068]
# 51 0.00014525541 [1.0136615] [-0.0310557]
# 52 0.00013835815 [1.013333] [-0.03030917]
# 53 0.00013178615 [1.0130125] [-0.02958053]
# 54 0.00012552558 [1.0126997] [-0.02886944]
# 55 0.00011956386 [1.0123944] [-0.02817546]
# 56 0.00011388446 [1.0120964] [-0.02749814]
# 57 0.00010847309 [1.0118057] [-0.02683707]
# 58 0.00010332153 [1.0115218] [-0.02619192]
# 59 9.84134e-05 [1.0112449] [-0.02556226]
# 60 9.373933e-05 [1.0109745] [-0.02494776]
# 61 8.928574e-05 [1.0107107] [-0.02434802]
# 62 8.504454e-05 [1.0104532] [-0.0237627]
# 63 8.1004786e-05 [1.0102019] [-0.02319145]
# 64 7.7156925e-05 [1.0099567] [-0.02263394]
# 65 7.349066e-05 [1.0097173] [-0.02208983]
# 66 7.0001006e-05 [1.0094838] [-0.0215588]
# 67 6.667627e-05 [1.0092558] [-0.02104057]
# 68 6.3507716e-05 [1.0090333] [-0.02053474]
# 69 6.049269e-05 [1.0088161] [-0.02004113]
# 70 5.7617613e-05 [1.0086043] [-0.01955934]
# 71 5.4881715e-05 [1.0083973] [-0.01908918]
# 72 5.2274714e-05 [1.0081955] [-0.01863028]
# 73 4.9792307e-05 [1.0079985] [-0.01818244]
# 74 4.7426507e-05 [1.0078062] [-0.01774534]
# 75 4.517366e-05 [1.0076185] [-0.01731874]
# 76 4.302847e-05 [1.0074353] [-0.01690242]
# 77 4.0984232e-05 [1.0072566] [-0.01649606]
# 78 3.9037288e-05 [1.0070822] [-0.0160995]
# 79 3.71832e-05 [1.006912] [-0.0157125]
# 80 3.5416917e-05 [1.0067458] [-0.01533479]
# 81 3.3734446e-05 [1.0065837] [-0.01496615]
# 82 3.213177e-05 [1.0064254] [-0.0146064]
# 83 3.0605748e-05 [1.0062709] [-0.01425527]
# 84 2.9152134e-05 [1.0061202] [-0.01391256]
# 85 2.7766999e-05 [1.0059731] [-0.01357813]
# 86 2.644833e-05 [1.0058295] [-0.01325173]
# 87 2.519231e-05 [1.0056893] [-0.01293317]
# 88 2.3995575e-05 [1.0055525] [-0.01262225]
# 89 2.2855233e-05 [1.0054191] [-0.0123188]
# 90 2.1769543e-05 [1.0052888] [-0.01202268]
# 91 2.0735797e-05 [1.0051616] [-0.01173368]
# 92 1.975024e-05 [1.0050377] [-0.01145159]
# 93 1.8812838e-05 [1.0049164] [-0.01117633]
# 94 1.7919148e-05 [1.0047983] [-0.01090763]
# 95 1.7067689e-05 [1.004683] [-0.01064541]
# 96 1.6257183e-05 [1.0045704] [-0.01038954]
# 97 1.548482e-05 [1.0044606] [-0.01013977]
# 98 1.4749679e-05 [1.0043533] [-0.00989604]
# 99 1.4048899e-05 [1.0042486] [-0.00965815]
# X: 5, Y: [5.0115848]
# X: 2.5, Y: [2.5009634]
